# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
business_data = pd.DataFrame({
    'Area':[
        'Customer Preferences',
        'Risk Assessment',
        'Social Media Marketing'
    ],
    'Impact Score':[85,90,88]
})

business_data
# Out:
#                      Area  Impact Score
# 0    Customer Preferences            85
# 1         Risk Assessment            90
# 2  Social Media Marketing            88

# %%
business_data.plot(
    x='Area',
    y='Impact Score',
    kind='bar',
    figsize=(8,5)
)

plt.title("Business Impact Areas")
plt.show()

# %%
actions = pd.DataFrame({
    'Action':[
        'Improve Customer Targeting',
        'Automate Loan Screening',
        'Optimize Posting Schedule',
        'Use Popular Hashtags',
        'Promote High Demand Services'
    ],
    'Priority':[5,5,4,4,5]
})

actions
# Out:
#                          Action  Priority
# 0    Improve Customer Targeting         5
# 1       Automate Loan Screening         5
# 2     Optimize Posting Schedule         4
# 3          Use Popular Hashtags         4
# 4  Promote High Demand Services         5

# %%
actions.plot(
    x='Action',
    y='Priority',
    kind='bar',
    figsize=(10,5)
)

plt.title("Recommended Business Actions")
plt.show()

# %% [markdown]
# # Findings
#
# 1. Customer behavior analysis helps identify popular products and services.
#
# 2. Predictive models can improve decision-making and reduce risk.
#
# 3. Social media analytics helps increase audience engagement and brand visibility.
#
# 4. Data-driven strategies improve operational efficiency.
#
# 5. Combining analytics from multiple domains provides better business insights.

# %% [markdown]
# # Recommended Actions for Alfido Tech
#
# 1. Use customer analytics to understand user preferences.
#
# 2. Apply predictive modeling for decision support systems.
#
# 3. Focus marketing efforts on peak engagement periods.
#
# 4. Use trending hashtags and content strategies to improve reach.
#
# 5. Build dashboards to continuously monitor business performance.

# %% [markdown]
# # Expected Business Impact
#
# - Improved customer engagement.
# - Better marketing performance.
# - Faster decision-making.
# - Reduced operational risk.
# - Increased business growth opportunities.

# %% [markdown]
# # Conclusion
#
# This capstone project combines insights from customer analytics, predictive modeling, and social media analysis to propose a data-driven growth strategy for Alfido Tech.
#
# The recommended actions can help improve operational efficiency, customer engagement, and overall business performance.
